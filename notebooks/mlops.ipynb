// %% [markdown]
// # mlops
// jupyter notebook mlops

// %%
// add packages
:dep polars = { version = "0.26.1", features = ["lazy", "temporal", "describe", "json", "parquet", "dtype-datetime"] }
:dep tokio = { version = "1", features = ["full"] }
:dep rayon = "1.8.0"

// %% [markdown]
// import package dependencies

// %%
// import dependencies
use polars::prelude::*;
use rayon::prelude::*;

// %% [markdown]
// load all coin data from crypto folder
// - crypto/*.csv
// - filter for XRP

// %%
let lf: LazyFrame = LazyCsvReader::new("../data/crypto/*.csv")
    .has_header(true)
    .finish()?;

let r = lf
    .filter(col("Symbol").eq(lit("XRP")))
    .collect()?;

r
// Out:
// shape: (2893, 10)
// ┌──────┬──────┬────────┬─────────────────────┬─────┬───────────┬──────────┬──────────┬───────────┐
// │ SNo  ┆ Name ┆ Symbol ┆ Date                ┆ ... ┆ Open      ┆ Close    ┆ Volume   ┆ Marketcap │
// │ ---  ┆ ---  ┆ ---    ┆ ---                 ┆     ┆ ---       ┆ ---      ┆ ---      ┆ ---       │
// │ i64  ┆ str  ┆ str    ┆ str                 ┆     ┆ f64       ┆ f64      ┆ f64      ┆ f64       │
// ╞══════╪══════╪════════╪═════════════════════╪═════╪═══════════╪══════════╪══════════╪═══════════╡
// │ 1    ┆ XRP  ┆ XRP    ┆ 2013-08-05 23:59:59 ┆ ... ┆ 0.005875  ┆ 0.005613 ┆ 0.0      ┆ 4.3879e7  │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2    ┆ XRP  ┆ XRP    ┆ 2013-08-06 23:59:59 ┆ ... ┆ 0.005637  ┆ 0.00468  ┆ 0.0      ┆ 3.6591e7  │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 3    ┆ XRP  ┆ XRP    ┆ 2013-08-07 23:59:59 ┆ ... ┆ 0.004669  ┆ 0.004417 ┆ 0.0      ┆ 3.4534e7  │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 4    ┆ XRP  ┆ XRP    ┆ 2013-08-08 23:59:59 ┆ ... ┆ 0.004397  ┆ 0.004254 ┆ 0.0      ┆ 3.3259e7  │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ ...  ┆ ...  ┆ ...    ┆ ...                 ┆ ... ┆ ...       ┆ ...      ┆ ...      ┆ ...       │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2890 ┆ XRP  ┆ XRP    ┆ 2021-07-03 23:59:59 ┆ ... ┆ 0.655639  ┆ 0.672888 ┆ 1.8728e9 ┆ 3.1052e10 │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2891 ┆ XRP  ┆ XRP    ┆ 2021-07-04 23:59:59 ┆ ... ┆ 0.673218  ┆ 0.694945 ┆ 1.8852e9 ┆ 3.2070e10 │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2892 ┆ XRP  ┆ XRP    ┆ 2021-07-05 23:59:59 ┆ ... ┆ 0.695653  ┆ 0.6543   ┆ 2.0764e9 ┆ 3.0194e10 │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2893 ┆ XRP  ┆ XRP    ┆ 2021-07-06 23:59:59 ┆ ... ┆ 0.6530552 ┆ 0.665402 ┆ 1.9390e9 ┆ 3.0723e10 │
// └──────┴──────┴────────┴─────────────────────┴─────┴───────────┴──────────┴──────────┴───────────┘

// %%
let lf: LazyFrame = LazyCsvReader::new("../data/crypto/*.csv")
    .has_header(true)
    .finish()?;

let r = lf
    .groupby([col("Name")])
    .agg(&[
        col("Volume").min().alias("min.volume"),
        col("Volume").mean().alias("avg.volume"),
        col("Volume").max().alias("max.max")
    ])
    .collect()?;

r
// Out:
// shape: (23, 4)
// ┌─────────────────┬──────────────┬────────────┬───────────┐
// │ Name            ┆ min.volume   ┆ avg.volume ┆ max.max   │
// │ ---             ┆ ---          ┆ ---        ┆ ---       │
// │ str             ┆ f64          ┆ f64        ┆ f64       │
// ╞═════════════════╪══════════════╪════════════╪═══════════╡
// │ Binance Coin    ┆ 9284.19043   ┆ 6.2698e8   ┆ 1.7983e10 │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ Dogecoin        ┆ 0.0          ┆ 4.3263e8   ┆ 6.9411e10 │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ Uniswap         ┆ 1.8936e8     ┆ 1.0616e9   ┆ 6.3729e9  │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ Crypto.com Coin ┆ 73880.514294 ┆ 5.0037e7   ┆ 1.9937e9  │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ ...             ┆ ...          ┆ ...        ┆ ...       │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ Ethereum        ┆ 102128.0     ┆ 7.0571e9   ┆ 8.4483e10 │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ Cosmos          ┆ 2.5672e6     ┆ 2.9634e8   ┆ 3.3659e9  │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ Wrapped Bitcoin ┆ 67.751993    ┆ 5.5479e7   ┆ 9.2176e8  │
// ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ NEM             ┆ 69.050797    ┆ 4.4281e7   ┆ 8.7073e9  │
// └─────────────────┴──────────────┴────────────┴───────────┘

// %%
let lf: LazyFrame = LazyCsvReader::new("../data/crypto/*.csv")
    .has_header(true)
    .finish()?;

let mut df = lf.collect()?;


let mut file = std::fs::File::create("../data/crypto/crypto.parquet").unwrap();
ParquetWriter::new(&mut file).finish(&mut df).unwrap();

// %%
let mut file = std::fs::File::open("../data/crypto/crypto.parquet")?;

let df = ParquetReader::new(&mut file).finish()?;
df
// Out:
// shape: (37082, 10)
// ┌──────┬──────┬────────┬────────────┬─────┬───────────┬───────────┬───────────────┬───────────┐
// │ SNo  ┆ Name ┆ Symbol ┆ Date       ┆ ... ┆ Open      ┆ Close     ┆ Volume        ┆ Marketcap │
// │ ---  ┆ ---  ┆ ---    ┆ ---        ┆     ┆ ---       ┆ ---       ┆ ---           ┆ ---       │
// │ i64  ┆ str  ┆ str    ┆ str        ┆     ┆ f64       ┆ f64       ┆ f64           ┆ f64       │
// ╞══════╪══════╪════════╪════════════╪═════╪═══════════╪═══════════╪═══════════════╪═══════════╡
// │ 1    ┆ Aave ┆ AAVE   ┆ 2020-10-05 ┆ ... ┆ 52.675035 ┆ 53.219243 ┆ 0.0           ┆ 8.9128e7  │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2    ┆ Aave ┆ AAVE   ┆ 2020-10-06 ┆ ... ┆ 53.291969 ┆ 42.401599 ┆ 583091.459763 ┆ 7.1011e7  │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 3    ┆ Aave ┆ AAVE   ┆ 2020-10-07 ┆ ... ┆ 42.399947 ┆ 40.083976 ┆ 682834.186323 ┆ 6.7130e7  │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 4    ┆ Aave ┆ AAVE   ┆ 2020-10-08 ┆ ... ┆ 39.885262 ┆ 43.764463 ┆ 1.6588e6      ┆ 2.2027e8  │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ ...  ┆ ...  ┆ ...    ┆ ...        ┆ ... ┆ ...       ┆ ...       ┆ ...           ┆ ...       │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2890 ┆ XRP  ┆ XRP    ┆ 2021-07-03 ┆ ... ┆ 0.655639  ┆ 0.672888  ┆ 1.8728e9      ┆ 3.1052e10 │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2891 ┆ XRP  ┆ XRP    ┆ 2021-07-04 ┆ ... ┆ 0.673218  ┆ 0.694945  ┆ 1.8852e9      ┆ 3.2070e10 │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2892 ┆ XRP  ┆ XRP    ┆ 2021-07-05 ┆ ... ┆ 0.695653  ┆ 0.6543    ┆ 2.0764e9      ┆ 3.0194e10 │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// ├╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
// │ 2893 ┆ XRP  ┆ XRP    ┆ 2021-07-06 ┆ ... ┆ 0.6530552 ┆ 0.665402  ┆ 1.9390e9      ┆ 3.0723e10 │
// │      ┆      ┆        ┆ 23:59:59   ┆     ┆           ┆           ┆               ┆           │
// └──────┴──────┴────────┴────────────┴─────┴───────────┴───────────┴───────────────┴───────────┘
